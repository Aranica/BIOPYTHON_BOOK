# %%
#[실습 02-01]

x=10
print(x)
print("자료형=",type(x))
# Out:
# 10
# 자료형= <class 'int'>

# %%
#[실습 02-02]

y=3.14
print(y)
print("자료형=",type(y))
print(x+y)
# Out:
# 3.14
# 자료형= <class 'float'>
# 13.14

# %%
#[실습 02-03]

z1 = "대한민국은"
z2 = "민주공화국이다"

print(z1), print("자료형=",type(z1))
print(z2), print("자료형=",type(z2))

z=z1+" "+z2
print(z)
# Out:
# 대한민국은
# 자료형= <class 'str'>
# 민주공화국이다
# 자료형= <class 'str'>
# 대한민국은 민주공화국이다

# %%
#[실습 02-04]

x1=[1,2,3]
print("x1=",x1,"자료형=",type(x1),"요소 수=",len(x1))

x2=["a","b","c","d"]
print("x2=",x2,"자료형=",type(x2),"요소 수=",len(x2))

x3=[x1,x2]
print("x3=",x3,"자료형=",type(x3),"요소 수=",len(x3))
# Out:
# x1= [1, 2, 3] 자료형= <class 'list'> 요소 수= 3
# x2= ['a', 'b', 'c', 'd'] 자료형= <class 'list'> 요소 수= 4
# x3= [[1, 2, 3], ['a', 'b', 'c', 'd']] 자료형= <class 'list'> 요소 수= 2

# %%
#[실습 02-05]

print("처음=",x1[0])
print("끝=",x1[-1])

x1[0]=5
print("변경된 리스트 x1=",x1)
# Out:
# 처음= 1
# 끝= 3
# 변경된 리스트 x1= [5, 2, 3]

# %%
#[실습 02-06]

t=(1,"a",3,x1)
print("t=",t)
print("자료=",type(t),"요소 수=",len(t))
# Out:
# t= (1, 'a', 3, [5, 2, 3])
# 자료= <class 'tuple'> 요소 수= 4

# %%
#[실습 02-07]

t[0]=5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 #[실습 02-07]
#       2
# ----> 3 t[0]=5
#
# TypeError: 'tuple' object does not support item assignment

# %%
#[실습 02-08]

d = {"영희":7852,"철수":5475,"민서":2279}

print("자료형=",type(d))
print()

print("키로 값 조회 -->",d["철수"])
print("쌍의 수=",len(d))
# Out:
# 자료형= <class 'dict'>
#
# 키로 값 조회 --> 5475
# 쌍의 수= 3

# %%
#[실습 02-09]

dat = {
    "학과": ["경영","인문","경영","인문","심리"],
    "이름": ["영희","철수","민서","지훈","동석"],
    "중간": [68,75,91,82,55],
    "기말": [85,90,80,95,100]
}

print("자료형=",type(dat));
print()
dat
# Out:
# 자료형= <class 'dict'>
# {'학과': ['경영', '인문', '경영', '인문', '심리'],
#  '이름': ['영희', '철수', '민서', '지훈', '동석'],
#  '중간': [68, 75, 91, 82, 55],
#  '기말': [85, 90, 80, 95, 100]}

# %%
#[실습 02-10]

df = pandas.core.frame.DataFrame(dat)
df
# Out:
#    학과  이름  중간   기말
# 0  경영  영희  68   85
# 1  인문  철수  75   90
# 2  경영  민서  91   80
# 3  인문  지훈  82   95
# 4  심리  동석  55  100

# %%
#[실습 02-11]

import pandas

df = pandas.core.frame.DataFrame(dat)
df
# Out:
#    학과  이름  중간   기말
# 0  경영  영희  68   85
# 1  인문  철수  75   90
# 2  경영  민서  91   80
# 3  인문  지훈  82   95
# 4  심리  동석  55  100

# %%
#[실습 02-12]

import pandas

df = pandas.DataFrame(dat)
df
# Out:
#    학과  이름  중간   기말
# 0  경영  영희  68   85
# 1  인문  철수  75   90
# 2  경영  민서  91   80
# 3  인문  지훈  82   95
# 4  심리  동석  55  100

# %%
#[실습 02-13]

import pandas as pd

df = pd.DataFrame(dat)
df
# Out:
#    학과  이름  중간   기말
# 0  경영  영희  68   85
# 1  인문  철수  75   90
# 2  경영  민서  91   80
# 3  인문  지훈  82   95
# 4  심리  동석  55  100

# %%
#[실습 02-14]

import matplotlib as plt

plt.plot(df["중간"])
plt.plot(df["기말"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 5
#       1 #[실습 02-14]
#       2
#       3 import matplotlib as plt
#       4
# ----> 5 plt.plot(df["중간"])
#       6 plt.plot(df["기말"])
#
# File /opt/anaconda3/envs/tf/lib/python3.11/site-packages/matplotlib/_api/__init__.py:318, in caching_module_getattr.<locals>.__getattr__(name)
#     316 if name in props:
#     317     return props[name].__get__(instance)
# --> 318 raise AttributeError(
#     319     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'plot'

# %%
#[실습 02-15]

import matplotlib.pyplot as plt

plt.plot(df["이름"],df["중간"])
plt.plot(df["이름"],df["기말"])
# Out:
# /opt/anaconda3/envs/tf/lib/python3.11/site-packages/IPython/core/events.py:101: UserWarning: Glyph 50689 (\N{HANGUL SYLLABLE YEONG}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /opt/anaconda3/envs/tf/lib/python3.11/site-packages/IPython/core/events.py:101: UserWarning: Glyph 55148 (\N{HANGUL SYLLABLE HYI}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /opt/anaconda3/envs/tf/lib/python3.11/site-packages/IPython/core/events.py:101: UserWarning: Glyph 52384 (\N{HANGUL SYLLABLE CEOL}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /opt/anaconda3/envs/tf/lib/python3.11/site-packages/IPython/core/events.py:101: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /opt/anaconda3/envs/tf/lib/python3.11/site-packages/IPython/core/events.py:101: UserWarning: Glyph 48124 (\N{HANGUL SYLLABLE MIN}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /opt/anaconda3/envs/tf/lib/python3.11/site-packages/IPython/core/events.py:101: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /opt/anaconda3/envs/tf/lib/python3.11/site-packages/IPython/core/events.py:101: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /opt/anaconda3/envs/tf/lib/python3.11/site-packages/IPython/core/events.py:101: UserWarning: Glyph 54984 (\N{HANGUL SYLLABLE HUN}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /opt/anaconda3/envs/tf/lib/python3.11/site-packages/IPython/core/events.py:101: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /opt/anaconda3/envs/tf/lib/python3.11/site-packages/IPython/core/events.py:101: UserWarning: Glyph 49437 (\N{HANGUL SYLLABLE SEOG}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /opt/anaconda3/envs/tf/lib/python3.11/site-packages/IPython/core/pylabtools.py:158: UserWarning: Glyph 50689 (\N{HANGUL SYLLABLE YEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/envs/tf/lib/python3.11/site-packages/IPython/core/pylabtools.py:158: UserWarning: Glyph 55148 (\N{HANGUL SYLLABLE HYI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/envs/tf/lib/python3.11/site-packages/IPython/core/pylabtools.py:158: UserWarning: Glyph 52384 (\N{HANGUL SYLLABLE CEOL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/envs/tf/lib/python3.11/site-packages/IPython/core/pylabtools.py:158: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/envs/tf/lib/python3.11/site-packages/IPython/core/pylabtools.py:158: UserWarning: Glyph 48124 (\N{HANGUL SYLLABLE MIN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/envs/tf/lib/python3.11/site-packages/IPython/core/pylabtools.py:158: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/envs/tf/lib/python3.11/site-packages/IPython/core/pylabtools.py:158: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/envs/tf/lib/python3.11/site-packages/IPython/core/pylabtools.py:158: UserWarning: Glyph 54984 (\N{HANGUL SYLLABLE HUN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/envs/tf/lib/python3.11/site-packages/IPython/core/pylabtools.py:158: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/envs/tf/lib/python3.11/site-packages/IPython/core/pylabtools.py:158: UserWarning: Glyph 49437 (\N{HANGUL SYLLABLE SEOG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#[실습 02-16]

# !pip install koreanize_matplotlib

import koreanize_matplotlib
# Out:
# Collecting koreanize_matplotlib
#   Using cached koreanize_matplotlib-0.1.1-py3-none-any.whl.metadata (992 bytes)
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/tf/lib/python3.11/site-packages (from koreanize_matplotlib) (3.11.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/tf/lib/python3.11/site-packages (from matplotlib->koreanize_matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/tf/lib/python3.11/site-packages (from matplotlib->koreanize_matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in /opt/anaconda3/envs/tf/lib/python3.11/site-packages (from matplotlib->koreanize_matplotlib) (4.65.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/tf/lib/python3.11/site-packages (from matplotlib->koreanize_matplotlib) (1.5.1)
# Requirement already satisfied: numpy>=1.25 in /opt/anaconda3/envs/tf/lib/python3.11/site-packages (from matplotlib->koreanize_matplotlib) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/tf/lib/python3.11/site-packages (from matplotlib->koreanize_matplotlib) (26.3)
# Requirement already satisfied: pillow>=9 in /opt/anaconda3/envs/tf/lib/python3.11/site-packages (from matplotlib->koreanize_matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in /opt/anaconda3/envs/tf/lib/python3.11/site-packages (from matplotlib->koreanize_matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/tf/lib/python3.11/site-packages (from matplotlib->koreanize_matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/tf/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->koreanize_matplotlib) (1.17.0)
# Using cached koreanize_matplotlib-0.1.1-py3-none-any.whl (7.9 MB)
# Installing collected packages: koreanize_matplotlib
# Successfully installed koreanize_matplotlib-0.1.1

# %%
#[실습 02-17]

plt.plot(df["이름"],df["중간"],color='g',marker='o',linestyle='-',label='중간고사')
plt.plot(df["이름"],df["기말"],color='r',marker='s',linestyle='--',label='기말고사')

plt.title("중간고사 점수와 기말고사 점수 비교")
plt.xlabel("이름")
plt.ylabel("점수")
plt.legend()

plt.show()

# %%
#[실습 02-18]

import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.metrics import r2_score, accuracy_score

# %%
#[실습 02-19]

df.to_csv("my_data.csv",encoding='cp949',index=False)

# %%
#[실습 02-20]

df=pd.read_csv("my_data.csv",encoding='cp949')
df
# Out:
#    학과  이름  중간   기말
# 0  경영  영희  68   85
# 1  인문  철수  75   90
# 2  경영  민서  91   80
# 3  인문  지훈  82   95
# 4  심리  동석  55  100

# %%
#[실습 02-23]

print("데이터 형태",df.shape); print()
print("행의 수",df.shape[0]); print()
print("열의 수",df.shape[1]); print()
print("열 이름",df.columns); print()
print("행 인덱스",df.index);
# Out:
# 데이터 형태 (5, 4)
#
# 행의 수 5
#
# 열의 수 4
#
# 열 이름 Index(['학과', '이름', '중간', '기말'], dtype='str')
#
# 행 인덱스 RangeIndex(start=0, stop=5, step=1)

# %%
#[실습 02-24]

print(df.head(3))
print()

print(df.tail(2))
# Out:
#    학과  이름  중간  기말
# 0  경영  영희  68  85
# 1  인문  철수  75  90
# 2  경영  민서  91  80
#
#    학과  이름  중간   기말
# 3  인문  지훈  82   95
# 4  심리  동석  55  100

# %%
#[실습 02-25]

df[["중간","기말"]].mean()
# Out:
# 중간    74.2
# 기말    90.0
# dtype: float64

# %%
#[실습 02-26]

df.groupby("학과")[["중간","기말"]].mean()
# Out:
#       중간     기말
# 학과
# 경영  79.5   82.5
# 심리  55.0  100.0
# 인문  78.5   92.5

# %%
#[실습 02-27]

df.groupby("학과")[["중간","기말"]].mean().plot.bar()

plt.title("학과별 평균 점수")
plt.show()
